# %%
import requests
import pandas as pd
from datetime import datetime
import google.cloud.logging
import logging
from google.cloud.logging.handlers import CloudLoggingHandler

# Initialize Google Cloud Logging client
client = google.cloud.logging.Client()
client.setup_logging()

# Create a logger
logger = logging.getLogger("app_scraping_logger")
logger.setLevel(logging.INFO)

# Define API parameters
start_date = '2024-05-01'
end_date = start_date  # Ensure this matches the context date
types_list = ['free', 'paid', 'grossing']  # List of app types
country = 'us'
device = 'iphone'
limit = 500


# Mapping of category codes to names
category_mapping = {
    "0": "All",
    "6018": "Books",
    "6000": "Business",
    "6026": "Developer Tools",
    "6017": "Education",
    "6016": "Entertainment",
    "6015": "Finance",
    "6023": "Food & Drink",
    # "6014": "Games",
    "6027": "Graphics & Design",
    "6013": "Health & Fitness",
    "6012": "Lifestyle",
    "6021": "Magazines & Newspapers",
    "6020": "Medical",
    "6011": "Music",
    "6010": "Navigation",
    "6009": "News",
    "6008": "Photo & Video",
    "6007": "Productivity",
    "6006": "Reference",
    "6005": "Social Networking",
    "6024": "Shopping",
    "6004": "Sports",
    "6003": "Travel",
    "6002": "Utilities",
    "6001": "Weather",
    # "7001": "Game Action",
    # "7002": "Game Adventure",
    # "7003": "Game Casual",
    # "7004": "Game Board",
    # "7005": "Game Card",
    # "7006": "Game Casino",
    # "7009": "Game Family",
    # "7011": "Game Music",
    # "7012": "Game Puzzle",
    # "7013": "Game Racing",
    # "7014": "Game Role Playing",
    # "7015": "Game Simulation",
    # "7016": "Game Sports",
    # "7017": "Game Strategy",
    # "7018": "Game Trivia",
    # "7019": "Game Word",
}

# Function to fetch data from the API
def fetch_data(category_code, start_date, end_date, app_type, country, device, limit):
    # Construct the request URL
    url = (f"https://public-api.apptweak.com/api/public/store/charts/top-results/history?"
           f"categories={category_code}&start_date={start_date}&end_date={end_date}&types={app_type}"
           f"&country={country}&device={device}&limit={limit}&offset=0")  # Fixed offset to 0

    headers = {
        "accept": "application/json",
        "x-apptweak-key": api_key
    }

    logger.info(f"Request URL: {url}")  # Log the request URL

    response = requests.get(url, headers=headers)

    # Log response status and body for debugging
    logger.info(f"Response Status: {response.status_code}")
    if response.status_code != 200:
        logger.error(f"Error fetching data: {response.status_code}, {response.text}")
        return None

    return response.json()

# Collect results for each type in the types_list
all_results = []

# Iterate through each category in the category mapping
for category_code, category_name in category_mapping.items():
    for app_type in types_list:  # Iterate through each app type
        data = fetch_data(category_code, start_date, end_date, app_type, country, device, limit)
        if data:
            # Extract the cost-related fields from the metadata section of the response
            request_metadata = data.get('metadata', {}).get('request', {})
            request_cost = request_metadata.get('cost')
            request_max_credit_cost = request_metadata.get('max_credit_cost')

            # Extract the results
            results = data.get('result', {}).get(category_code, {}).get(app_type, [])
            if results:
                # Extract values from the results
                for app in results:
                    app_date = app['date']  # Extract the 'date' field from the response
                    # Enumerate through the values to assign ranks based on their order
                    for rank, value in enumerate(app['value'], start=1):
                        all_results.append({
                            "scraping_url": f"https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories={category_code}&start_date={start_date}&end_date={end_date}&types={app_type}&country={country}&device={device}&limit={limit}&offset=0",
                            "scraping_timestamp": int(datetime.now().timestamp() * 1_000_000),  # Current timestamp
                            "category_code": category_code,
                            "category_name": category_name,  # Use the category name from mapping
                            "context_date": app_date,  # Use the 'date' field from the response as context_date
                            "type": app_type,  # Update type to the current app type
                            "country": country,
                            "device": device,
                            "rank": rank,  # Rank assigned based on the order of appearance
                            "app_store_id": value,  # Include value for clarity
                            "request_cost": request_cost,  # Add request cost
                            "request_max_credit_cost": request_max_credit_cost  # Add max credit cost
                        })
            else:
                logger.warning(f"No results found for category {category_name} and type {app_type}")

# Output the results
if all_results:
    # Create a DataFrame from the results
    df_results = pd.DataFrame(all_results)
    logger.info(f"Scraping completed successfully. Total records: {len(all_results)}")
else:
    logger.warning("No data to upload.")
# Out:
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=0&start_date=2024-05-01&end_date=2024-05-01&types=free&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=0&start_date=2024-05-01&end_date=2024-05-01&types=paid&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=0&start_date=2024-05-01&end_date=2024-05-01&types=grossing&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6018&start_date=2024-05-01&end_date=2024-05-01&types=free&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6018&start_date=2024-05-01&end_date=2024-05-01&types=paid&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6018&start_date=2024-05-01&end_date=2024-05-01&types=grossing&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6000&start_date=2024-05-01&end_date=2024-05-01&types=free&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6000&start_date=2024-05-01&end_date=2024-05-01&types=paid&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6000&start_date=2024-05-01&end_date=2024-05-01&types=grossing&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6026&start_date=2024-05-01&end_date=2024-05-01&types=free&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6026&start_date=2024-05-01&end_date=2024-05-01&types=paid&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6026&start_date=2024-05-01&end_date=2024-05-01&types=grossing&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6017&start_date=2024-05-01&end_date=2024-05-01&types=free&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6017&start_date=2024-05-01&end_date=2024-05-01&types=paid&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6017&start_date=2024-05-01&end_date=2024-05-01&types=grossing&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6016&start_date=2024-05-01&end_date=2024-05-01&types=free&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6016&start_date=2024-05-01&end_date=2024-05-01&types=paid&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6016&start_date=2024-05-01&end_date=2024-05-01&types=grossing&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6015&start_date=2024-05-01&end_date=2024-05-01&types=free&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6015&start_date=2024-05-01&end_date=2024-05-01&types=paid&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6015&start_date=2024-05-01&end_date=2024-05-01&types=grossing&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6023&start_date=2024-05-01&end_date=2024-05-01&types=free&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6023&start_date=2024-05-01&end_date=2024-05-01&types=paid&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6023&start_date=2024-05-01&end_date=2024-05-01&types=grossing&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6027&start_date=2024-05-01&end_date=2024-05-01&types=free&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6027&start_date=2024-05-01&end_date=2024-05-01&types=paid&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6027&start_date=2024-05-01&end_date=2024-05-01&types=grossing&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6013&start_date=2024-05-01&end_date=2024-05-01&types=free&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6013&start_date=2024-05-01&end_date=2024-05-01&types=paid&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6013&start_date=2024-05-01&end_date=2024-05-01&types=grossing&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6012&start_date=2024-05-01&end_date=2024-05-01&types=free&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6012&start_date=2024-05-01&end_date=2024-05-01&types=paid&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6012&start_date=2024-05-01&end_date=2024-05-01&types=grossing&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6021&start_date=2024-05-01&end_date=2024-05-01&types=free&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6021&start_date=2024-05-01&end_date=2024-05-01&types=paid&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6021&start_date=2024-05-01&end_date=2024-05-01&types=grossing&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6020&start_date=2024-05-01&end_date=2024-05-01&types=free&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6020&start_date=2024-05-01&end_date=2024-05-01&types=paid&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6020&start_date=2024-05-01&end_date=2024-05-01&types=grossing&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6011&start_date=2024-05-01&end_date=2024-05-01&types=free&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6011&start_date=2024-05-01&end_date=2024-05-01&types=paid&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6011&start_date=2024-05-01&end_date=2024-05-01&types=grossing&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6010&start_date=2024-05-01&end_date=2024-05-01&types=free&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6010&start_date=2024-05-01&end_date=2024-05-01&types=paid&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6010&start_date=2024-05-01&end_date=2024-05-01&types=grossing&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6009&start_date=2024-05-01&end_date=2024-05-01&types=free&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6009&start_date=2024-05-01&end_date=2024-05-01&types=paid&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6009&start_date=2024-05-01&end_date=2024-05-01&types=grossing&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6008&start_date=2024-05-01&end_date=2024-05-01&types=free&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6008&start_date=2024-05-01&end_date=2024-05-01&types=paid&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6008&start_date=2024-05-01&end_date=2024-05-01&types=grossing&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6007&start_date=2024-05-01&end_date=2024-05-01&types=free&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6007&start_date=2024-05-01&end_date=2024-05-01&types=paid&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6007&start_date=2024-05-01&end_date=2024-05-01&types=grossing&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6006&start_date=2024-05-01&end_date=2024-05-01&types=free&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6006&start_date=2024-05-01&end_date=2024-05-01&types=paid&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6006&start_date=2024-05-01&end_date=2024-05-01&types=grossing&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6005&start_date=2024-05-01&end_date=2024-05-01&types=free&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6005&start_date=2024-05-01&end_date=2024-05-01&types=paid&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6005&start_date=2024-05-01&end_date=2024-05-01&types=grossing&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6024&start_date=2024-05-01&end_date=2024-05-01&types=free&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6024&start_date=2024-05-01&end_date=2024-05-01&types=paid&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6024&start_date=2024-05-01&end_date=2024-05-01&types=grossing&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6004&start_date=2024-05-01&end_date=2024-05-01&types=free&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6004&start_date=2024-05-01&end_date=2024-05-01&types=paid&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6004&start_date=2024-05-01&end_date=2024-05-01&types=grossing&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6003&start_date=2024-05-01&end_date=2024-05-01&types=free&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6003&start_date=2024-05-01&end_date=2024-05-01&types=paid&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6003&start_date=2024-05-01&end_date=2024-05-01&types=grossing&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6002&start_date=2024-05-01&end_date=2024-05-01&types=free&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6002&start_date=2024-05-01&end_date=2024-05-01&types=paid&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6002&start_date=2024-05-01&end_date=2024-05-01&types=grossing&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6001&start_date=2024-05-01&end_date=2024-05-01&types=free&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6001&start_date=2024-05-01&end_date=2024-05-01&types=paid&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Request URL: https://public-api.apptweak.com/api/public/store/charts/top-results/history?categories=6001&start_date=2024-05-01&end_date=2024-05-01&types=grossing&country=us&device=iphone&limit=500&offset=0
# INFO:app_scraping_logger:Response Status: 200
# INFO:app_scraping_logger:Scraping completed successfully. Total records: 27977

# %%
df_results.head()
# Out:
#                                         scraping_url  scraping_timestamp  \
# 0  https://public-api.apptweak.com/api/public/sto...    1727351578366590
# 1  https://public-api.apptweak.com/api/public/sto...    1727351578366601
# 2  https://public-api.apptweak.com/api/public/sto...    1727351578366606
# 3  https://public-api.apptweak.com/api/public/sto...    1727351578366610
# 4  https://public-api.apptweak.com/api/public/sto...    1727351578366615
#
#   category_code category_name context_date  type country  device  rank  \
# 0             0           All   2024-05-01  free      us  iphone     1
# 1             0           All   2024-05-01  free      us  iphone     2
# 2             0           All   2024-05-01  free      us  iphone     3
# 3             0           All   2024-05-01  free      us  iphone     4
# 4             0           All   2024-05-01  free      us  iphone     5
#
#    app_store_id  request_cost  request_max_credit_cost
# 0    1048524688            11                       11
# 1     482752836            11                       11
# 2     284815942            11                       11
# 3    6446901002            11                       11
# 4    1641486558            11                       11

# %%
import logging
import pandas as pd
from google.cloud import storage
import google.cloud.logging
from google.cloud.logging.handlers import CloudLoggingHandler

# Setup Google Cloud Logging client and logger
client = google.cloud.logging.Client()
handler = CloudLoggingHandler(client)
logger = logging.getLogger('stackdriver_logger')
logger.setLevel(logging.INFO)
logger.addHandler(handler)

# Define your GCS bucket name
bucket_name = 'top_chart'

# Assume `start_date` and `end_date` come from your API request
# start_date = '2024-09-24'
# end_date = '2024-09-24'

# Define the file name based on start_date and end_date, using underscores
parquet_file_name = f'top_app_chart_{start_date.replace("-", "_")}_to_{end_date.replace("-", "_")}.parquet'

# Initialize the GCS client
storage_client = storage.Client()
bucket = storage_client.bucket(bucket_name)
blob = bucket.blob(parquet_file_name)

try:
    # Check if the DataFrame is not empty
    if not df_results.empty:
        # Check if the file already exists for the given date range
        if blob.exists():
            logger.info(f"Overwriting existing file: {parquet_file_name} for date range {start_date} to {end_date}")
        else:
            logger.info(f"Uploading new file: {parquet_file_name} for date range {start_date} to {end_date}")

        # Save the DataFrame to Parquet format in the GCS bucket
        df_results.to_parquet(f'gs://{bucket_name}/{parquet_file_name}', index=False)

        logger.info(f"DataFrame saved to gs://{bucket_name}/{parquet_file_name}")
    else:
        logger.warning("No data to upload.")
except Exception as e:
    logger.error(f"An error occurred: {e}")
# Out:
# INFO:stackdriver_logger:Uploading new file: top_app_chart_2024_05_01_to_2024_05_01.parquet for date range 2024-05-01 to 2024-05-01
# INFO:stackdriver_logger:DataFrame saved to gs://top_chart/top_app_chart_2024_05_01_to_2024_05_01.parquet

# %% [markdown]
# ### Load to BQ

# %%
import logging
from google.cloud import bigquery, storage
import google.cloud.logging
from google.cloud.logging.handlers import CloudLoggingHandler

# Initialize Stackdriver Logging client and logger
logging_client = google.cloud.logging.Client()
handler = CloudLoggingHandler(logging_client)
logger = logging.getLogger('stackdriver_logger')
logger.setLevel(logging.INFO)
logger.addHandler(handler)

# Initialize GCS and BigQuery clients
gcs_client = storage.Client()
bq_client = bigquery.Client()

# Define your parameters
project_id = "web-scraping-2024"
dataset_id = "top_chart"
bucket_name = "top_chart"
top_chart_dir_prefix = ""  # You can add a prefix if needed
specific_file_name = ".parquet"  # We're interested in all files with the .parquet extension

def list_parquet_files(bucket_name, prefix):
    """List all Parquet files in a GCS bucket and prefix."""
    try:
        bucket = gcs_client.bucket(bucket_name)
        blobs = bucket.list_blobs(prefix=prefix)
        return [blob.name for blob in blobs if blob.name.endswith('.parquet')]
    except Exception as e:
        logger.error(f"Error listing parquet files: {e}")
        return []

# Load all Parquet files
top_chart_details_files = list_parquet_files(bucket_name, top_chart_dir_prefix)

if not top_chart_details_files:
    logger.warning("No Parquet files found.")
else:
    top_chart_table_ref = bq_client.dataset(dataset_id).table("top_chart")
    top_chart_job_config = bigquery.LoadJobConfig(
        source_format=bigquery.SourceFormat.PARQUET,  # Parquet file format
        autodetect=True
    )

    for file in top_chart_details_files:
        try:
            # Start the load job for each Parquet file
            logger.info(f"Loading file: {file} into BigQuery")
            load_job = bq_client.load_table_from_uri(
                f"gs://{bucket_name}/{file}",
                top_chart_table_ref,
                job_config=top_chart_job_config
            )

            # Wait for the job to complete
            load_job.result()  # This blocks until the job finishes.

            # Log the result for each file
            logger.info(f"Successfully loaded file {file} into {dataset_id}:top_chart.")

        except Exception as e:
            logger.error(f"Error loading file {file}: {e}")

    # Check the result for the entire table
    try:
        apptweak_details_table = bq_client.get_table(top_chart_table_ref)
        logger.info(f"Loaded {apptweak_details_table.num_rows} rows into {dataset_id}:top_chart.")
    except Exception as e:
        logger.error(f"Error fetching table details: {e}")
# Out:
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_05_01_to_2024_05_01.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_05_01_to_2024_05_01.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_05_02_to_2024_05_02.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_05_02_to_2024_05_02.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_05_03_to_2024_05_03.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_05_03_to_2024_05_03.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_05_04_to_2024_05_04.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_05_04_to_2024_05_04.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_05_05_to_2024_05_05.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_05_05_to_2024_05_05.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_05_06_to_2024_05_06.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_05_06_to_2024_05_06.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_05_07_to_2024_05_07.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_05_07_to_2024_05_07.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_05_08_to_2024_05_08.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_05_08_to_2024_05_08.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_05_09_to_2024_05_09.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_05_09_to_2024_05_09.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_05_10_to_2024_05_10.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_05_10_to_2024_05_10.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_05_11_to_2024_05_11.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_05_11_to_2024_05_11.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_05_12_to_2024_05_12.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_05_12_to_2024_05_12.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_05_13_to_2024_05_13.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_05_13_to_2024_05_13.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_05_14_to_2024_05_14.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_05_14_to_2024_05_14.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_05_15_to_2024_05_15.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_05_15_to_2024_05_15.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_05_16_to_2024_05_16.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_05_16_to_2024_05_16.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_05_17_to_2024_05_17.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_05_17_to_2024_05_17.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_05_18_to_2024_05_18.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_05_18_to_2024_05_18.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_05_19_to_2024_05_19.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_05_19_to_2024_05_19.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_05_20_to_2024_05_20.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_05_20_to_2024_05_20.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_05_21_to_2024_05_21.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_05_21_to_2024_05_21.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_05_22_to_2024_05_22.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_05_22_to_2024_05_22.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_05_23_to_2024_05_23.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_05_23_to_2024_05_23.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_05_24_to_2024_05_24.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_05_24_to_2024_05_24.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_05_25_to_2024_05_25.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_05_25_to_2024_05_25.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_05_26_to_2024_05_26.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_05_26_to_2024_05_26.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_05_27_to_2024_05_27.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_05_27_to_2024_05_27.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_05_28_to_2024_05_28.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_05_28_to_2024_05_28.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_05_29_to_2024_05_29.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_05_29_to_2024_05_29.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_05_30_to_2024_05_30.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_05_30_to_2024_05_30.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_05_31_to_2024_05_31.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_05_31_to_2024_05_31.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_06_01_to_2024_06_01.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_06_01_to_2024_06_01.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_06_02_to_2024_06_02.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_06_02_to_2024_06_02.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_06_03_to_2024_06_03.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_06_03_to_2024_06_03.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_06_04_to_2024_06_04.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_06_04_to_2024_06_04.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_06_05_to_2024_06_05.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_06_05_to_2024_06_05.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_06_06_to_2024_06_06.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_06_06_to_2024_06_06.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_06_07_to_2024_06_07.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_06_07_to_2024_06_07.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_06_08_to_2024_06_08.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_06_08_to_2024_06_08.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_06_09_to_2024_06_09.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_06_09_to_2024_06_09.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_06_10_to_2024_06_10.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_06_10_to_2024_06_10.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_06_11_to_2024_06_11.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_06_11_to_2024_06_11.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_06_12_to_2024_06_12.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_06_12_to_2024_06_12.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_06_13_to_2024_06_13.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_06_13_to_2024_06_13.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_06_14_to_2024_06_14.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_06_14_to_2024_06_14.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_06_15_to_2024_06_15.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_06_15_to_2024_06_15.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_06_16_to_2024_06_16.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_06_16_to_2024_06_16.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_06_17_to_2024_06_17.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_06_17_to_2024_06_17.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_06_18_to_2024_06_18.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_06_18_to_2024_06_18.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_06_19_to_2024_06_19.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_06_19_to_2024_06_19.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_06_20_to_2024_06_20.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_06_20_to_2024_06_20.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_06_21_to_2024_06_21.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_06_21_to_2024_06_21.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_06_22_to_2024_06_22.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_06_22_to_2024_06_22.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_06_23_to_2024_06_23.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_06_23_to_2024_06_23.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_06_24_to_2024_06_24.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_06_24_to_2024_06_24.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_06_25_to_2024_06_25.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_06_25_to_2024_06_25.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_06_26_to_2024_06_26.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_06_26_to_2024_06_26.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_06_27_to_2024_06_27.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_06_27_to_2024_06_27.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_06_28_to_2024_06_28.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_06_28_to_2024_06_28.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_06_29_to_2024_06_29.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_06_29_to_2024_06_29.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_06_30_to_2024_06_30.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_06_30_to_2024_06_30.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_07_01_to_2024_07_01.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_07_01_to_2024_07_01.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_07_02_to_2024_07_02.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_07_02_to_2024_07_02.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_07_03_to_2024_07_03.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_07_03_to_2024_07_03.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_07_04_to_2024_07_04.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_07_04_to_2024_07_04.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_07_05_to_2024_07_05.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_07_05_to_2024_07_05.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_07_06_to_2024_07_06.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_07_06_to_2024_07_06.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_07_07_to_2024_07_07.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_07_07_to_2024_07_07.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_07_08_to_2024_07_08.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_07_08_to_2024_07_08.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_07_09_to_2024_07_09.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_07_09_to_2024_07_09.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_07_10_to_2024_07_10.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_07_10_to_2024_07_10.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_07_11_to_2024_07_11.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_07_11_to_2024_07_11.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_07_12_to_2024_07_12.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_07_12_to_2024_07_12.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_07_13_to_2024_07_13.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_07_13_to_2024_07_13.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_07_14_to_2024_07_14.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_07_14_to_2024_07_14.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_07_15_to_2024_07_15.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_07_15_to_2024_07_15.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_07_16_to_2024_07_16.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_07_16_to_2024_07_16.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_07_17_to_2024_07_17.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_07_17_to_2024_07_17.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_07_18_to_2024_07_18.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_07_18_to_2024_07_18.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_07_19_to_2024_07_19.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_07_19_to_2024_07_19.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_07_20_to_2024_07_20.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_07_20_to_2024_07_20.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_07_21_to_2024_07_21.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_07_21_to_2024_07_21.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_07_22_to_2024_07_22.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_07_22_to_2024_07_22.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_07_23_to_2024_07_23.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_07_23_to_2024_07_23.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_07_24_to_2024_07_24.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_07_24_to_2024_07_24.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_07_25_to_2024_07_25.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_07_25_to_2024_07_25.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_07_26_to_2024_07_26.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_07_26_to_2024_07_26.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_07_27_to_2024_07_27.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_07_27_to_2024_07_27.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_07_28_to_2024_07_28.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_07_28_to_2024_07_28.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_07_29_to_2024_07_29.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_07_29_to_2024_07_29.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_07_30_to_2024_07_30.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_07_30_to_2024_07_30.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_07_31_to_2024_07_31.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_07_31_to_2024_07_31.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_08_01_to_2024_08_01.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_08_01_to_2024_08_01.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_08_02_to_2024_08_02.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_08_02_to_2024_08_02.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_08_03_to_2024_08_03.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_08_03_to_2024_08_03.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_08_04_to_2024_08_04.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_08_04_to_2024_08_04.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_08_05_to_2024_08_05.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_08_05_to_2024_08_05.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_08_06_to_2024_08_06.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_08_06_to_2024_08_06.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_08_07_to_2024_08_07.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_08_07_to_2024_08_07.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_08_08_to_2024_08_08.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_08_08_to_2024_08_08.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_08_09_to_2024_08_09.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_08_09_to_2024_08_09.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_08_10_to_2024_08_10.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_08_10_to_2024_08_10.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_08_11_to_2024_08_11.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_08_11_to_2024_08_11.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_08_12_to_2024_08_12.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_08_12_to_2024_08_12.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_08_13_to_2024_08_13.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_08_13_to_2024_08_13.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_08_14_to_2024_08_14.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_08_14_to_2024_08_14.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_08_15_to_2024_08_15.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_08_15_to_2024_08_15.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_08_16_to_2024_08_16.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_08_16_to_2024_08_16.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_08_17_to_2024_08_17.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_08_17_to_2024_08_17.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_08_18_to_2024_08_18.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_08_18_to_2024_08_18.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_08_19_to_2024_08_19.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_08_19_to_2024_08_19.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_08_20_to_2024_08_20.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_08_20_to_2024_08_20.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_08_21_to_2024_08_21.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_08_21_to_2024_08_21.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_08_22_to_2024_08_22.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_08_22_to_2024_08_22.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_08_23_to_2024_08_23.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_08_23_to_2024_08_23.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_08_24_to_2024_08_24.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_08_24_to_2024_08_24.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_08_25_to_2024_08_25.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_08_25_to_2024_08_25.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_08_26_to_2024_08_26.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_08_26_to_2024_08_26.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_08_27_to_2024_08_27.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_08_27_to_2024_08_27.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_08_28_to_2024_08_28.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_08_28_to_2024_08_28.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_08_29_to_2024_08_29.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_08_29_to_2024_08_29.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_08_30_to_2024_08_30.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_08_30_to_2024_08_30.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_08_31_to_2024_08_31.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_08_31_to_2024_08_31.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_09_01_to_2024_09_01.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_09_01_to_2024_09_01.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_09_02_to_2024_09_02.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_09_02_to_2024_09_02.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_09_03_to_2024_09_03.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_09_03_to_2024_09_03.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_09_04_to_2024_09_04.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_09_04_to_2024_09_04.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_09_05_to_2024_09_05.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_09_05_to_2024_09_05.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_09_06_to_2024_09_06.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_09_06_to_2024_09_06.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_09_07_to_2024_09_07.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_09_07_to_2024_09_07.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_09_08_to_2024_09_08.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_09_08_to_2024_09_08.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_09_09_to_2024_09_09.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_09_09_to_2024_09_09.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_09_10_to_2024_09_10.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_09_10_to_2024_09_10.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_09_11_to_2024_09_11.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_09_11_to_2024_09_11.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_09_12_to_2024_09_12.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_09_12_to_2024_09_12.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_09_13_to_2024_09_13.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_09_13_to_2024_09_13.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_09_14_to_2024_09_14.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_09_14_to_2024_09_14.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_09_15_to_2024_09_15.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_09_15_to_2024_09_15.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_09_16_to_2024_09_16.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_09_16_to_2024_09_16.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_09_17_to_2024_09_17.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_09_17_to_2024_09_17.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_09_18_to_2024_09_18.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_09_18_to_2024_09_18.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_09_19_to_2024_09_19.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_09_19_to_2024_09_19.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_09_20_to_2024_09_20.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_09_20_to_2024_09_20.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_09_21_to_2024_09_21.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_09_21_to_2024_09_21.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_09_22_to_2024_09_22.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_09_22_to_2024_09_22.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_09_23_to_2024_09_23.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_09_23_to_2024_09_23.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_09_24_to_2024_09_24.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_09_24_to_2024_09_24.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loading file: top_app_chart_2024_09_25_to_2024_09_25.parquet into BigQuery
# INFO:stackdriver_logger:Successfully loaded file top_app_chart_2024_09_25_to_2024_09_25.parquet into top_chart:top_chart.
# INFO:stackdriver_logger:Loaded 4156051 rows into top_chart:top_chart.
